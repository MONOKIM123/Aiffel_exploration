# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# !ls '/gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/2. Exploration 수업/코드/16강'
# Out:
# CGAN_500.data-00000-of-00002  GAN_500.data-00000-of-00002  project16_ex1.ipynb
# CGAN_500.data-00001-of-00002  GAN_500.data-00001-of-00002  project16.ipynb
# CGAN_500.index		      GAN_500.index		   train
# cityscapes		      project16_2.ipynb

# %% [markdown]
# # 데이터 로드

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

import random
from glob import glob
import os
import cv2
from google.colab.patches import cv2_imshow

# %%
working_dir = '/gdrive/MyDrive/0. 인공지능 학습/아이펠 대전 3기/2. Exploration 수업/코드/16강'
train_img_paths = glob(os.path.join(working_dir, "cityscapes/train/*.jpg"))
test_img_paths = glob(os.path.join(working_dir, "cityscapes/test/*.jpg"))
print(f"학습 데이터셋 길이 : {len(train_img_paths)}")
print(f"테스트 데이터셋 길이 : {len(test_img_paths)}")
# Out:
# 학습 데이터셋 길이 : 1000
# 테스트 데이터셋 길이 : 5

# %%
random_img_index = random.randint(0, len(train_img_paths)-1)
img = cv2.imread(train_img_paths[random_img_index])
cv2_imshow(img)
print(f"학습 이미지 차원 : ({img.shape})")
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F2254900950>
# 학습 이미지 차원 : ((256, 512, 3))

# %% [markdown]
# # 데이터 전처리

# %%
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, w:, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, :w, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

# %%
random_img_index = random.randint(0, len(train_img_paths))
f = train_img_paths[random_img_index]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    if tf.random.uniform(()) < .5:
        stacked = tf.concat([sketch, colored], axis=-1)
        out = image.random_flip_left_right(stacked)
    else:
        stacked = tf.concat([sketch, colored], axis=-1)
        out = stacked
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,4))
img_n = 1
for i in range(1, 5, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(1,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(1,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %% [markdown]
# - 이미지 증강에서 확대 회전 시 실제 환경에서 발생하지 않을 이미지들이 생성되기 때문에 좌우 반전 이미지 증강만 사용한다.

# %% [markdown]
# # Data Loader

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

# %%
train_images = data.Dataset.list_files(train_img_paths)
train_images = train_images.map(get_train).shuffle(1000).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # 모델 설계

# %% [markdown]
# ## U-net을 이용한 생성 모델

# %% [markdown]
# ### Encoder

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  encode_block (EncodeBlock)  (None, 128, 128, 64)      3072
#
#  encode_block_1 (EncodeBlock  (None, 64, 64, 128)      131584
#  )
#
#  encode_block_2 (EncodeBlock  (None, 32, 32, 256)      525312
#  )
#
#  encode_block_3 (EncodeBlock  (None, 16, 16, 512)      2099200
#  )
#
#  encode_block_4 (EncodeBlock  (None, 8, 8, 512)        4196352
#  )
#
#  encode_block_5 (EncodeBlock  (None, 4, 4, 512)        4196352
#  )
#
#  encode_block_6 (EncodeBlock  (None, 2, 2, 512)        4196352
#  )
#
#  encode_block_7 (EncodeBlock  (None, 1, 1, 512)        4196352
#  )
#
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Decoder

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1, 1, 512)]       0
#
#  decode_block (DecodeBlock)  (None, 2, 2, 512)         4196352
#
#  decode_block_1 (DecodeBlock  (None, 4, 4, 512)        4196352
#  )
#
#  decode_block_2 (DecodeBlock  (None, 8, 8, 512)        4196352
#  )
#
#  decode_block_3 (DecodeBlock  (None, 16, 16, 512)      4196352
#  )
#
#  decode_block_4 (DecodeBlock  (None, 32, 32, 256)      2098176
#  )
#
#  decode_block_5 (DecodeBlock  (None, 64, 64, 128)      524800
#  )
#
#  decode_block_6 (DecodeBlock  (None, 128, 128, 64)     131328
#  )
#
#  conv2d_transpose_7 (Conv2DT  (None, 256, 256, 3)      3072
#  ranspose)
#
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  encoder_1 (Encoder)         (None, 1, 1, 512)         19544576
#
#  decoder_1 (Decoder)         (None, 256, 256, 3)       19542784
#
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  encode_block_16 (EncodeBlock)  (None, 128, 128, 64  3072        ['input_4[0][0]']
#                                 )
#
#  encode_block_17 (EncodeBlock)  (None, 64, 64, 128)  131584      ['encode_block_16[0][0]']
#
#  encode_block_18 (EncodeBlock)  (None, 32, 32, 256)  525312      ['encode_block_17[0][0]']
#
#  encode_block_19 (EncodeBlock)  (None, 16, 16, 512)  2099200     ['encode_block_18[0][0]']
#
#  encode_block_20 (EncodeBlock)  (None, 8, 8, 512)    4196352     ['encode_block_19[0][0]']
#
#  encode_block_21 (EncodeBlock)  (None, 4, 4, 512)    4196352     ['encode_block_20[0][0]']
#
#  encode_block_22 (EncodeBlock)  (None, 2, 2, 512)    4196352     ['encode_block_21[0][0]']
#
#  encode_block_23 (EncodeBlock)  (None, 1, 1, 512)    4196352     ['encode_block_22[0][0]']
#
#  decode_block_14 (DecodeBlock)  (None, 2, 2, 512)    4196352     ['encode_block_23[0][0]']
#
#  concatenate (Concatenate)      (None, 2, 2, 1024)   0           ['decode_block_14[0][0]',
#                                                                   'encode_block_22[0][0]']
#
#  decode_block_15 (DecodeBlock)  (None, 4, 4, 512)    8390656     ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 1024)   0           ['decode_block_15[0][0]',
#                                                                   'encode_block_21[0][0]']
#
#  decode_block_16 (DecodeBlock)  (None, 8, 8, 512)    8390656     ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 1024)   0           ['decode_block_16[0][0]',
#                                                                   'encode_block_20[0][0]']
#
#  decode_block_17 (DecodeBlock)  (None, 16, 16, 512)  8390656     ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 1024  0           ['decode_block_17[0][0]',
#                                 )                                 'encode_block_19[0][0]']
#
#  decode_block_18 (DecodeBlock)  (None, 32, 32, 256)  4195328     ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 512)  0           ['decode_block_18[0][0]',
#                                                                   'encode_block_18[0][0]']
#
#  decode_block_19 (DecodeBlock)  (None, 64, 64, 128)  1049088     ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 256)  0           ['decode_block_19[0][0]',
#                                                                   'encode_block_17[0][0]']
#
#  decode_block_20 (DecodeBlock)  (None, 128, 128, 64  262400      ['concatenate_5[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 12  0           ['decode_block_20[0][0]',
#                                 8)                                'encode_block_16[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 256, 256, 3)  6144       ['concatenate_6[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ## 판별 모델

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 128, 128, 32)]    0
#
#  zero_padding2d (ZeroPadding  (None, 130, 130, 32)     0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 127, 127, 64)      32768
#
#  batch_normalization_45 (Bat  (None, 127, 127, 64)     256
#  chNormalization)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 127, 127, 64)      0
#
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_7 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 6)  0           ['input_6[0][0]',
#                                                                   'input_7[0][0]']
#
#  disc_block (DiscBlock)         (None, 128, 128, 64  6144        ['concatenate_7[0][0]']
#                                 )
#
#  disc_block_1 (DiscBlock)       (None, 64, 64, 128)  131584      ['disc_block[0][0]']
#
#  disc_block_2 (DiscBlock)       (None, 32, 32, 256)  525312      ['disc_block_1[0][0]']
#
#  disc_block_3 (DiscBlock)       (None, 31, 31, 512)  2099200     ['disc_block_2[0][0]']
#
#  disc_block_4 (DiscBlock)       (None, 30, 30, 1)    8192        ['disc_block_3[0][0]']
#
#  activation (Activation)        (None, 30, 30, 1)    0           ['disc_block_4[0][0]']
#
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
generator = UNetGenerator()
discriminator = Discriminator()

# %%
EPOCHS = 300

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 50 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# EPOCH[101] - STEP[50]
# Generator_loss:2.6432
# L1_loss:0.0883
# Discriminator_loss:1.2711
#
# EPOCH[101] - STEP[100]
# Generator_loss:0.8409
# L1_loss:0.0908
# Discriminator_loss:0.8398
#
# EPOCH[101] - STEP[150]
# Generator_loss:1.6186
# L1_loss:0.0931
# Discriminator_loss:0.3998
#
# EPOCH[101] - STEP[200]
# Generator_loss:1.2211
# L1_loss:0.1042
# Discriminator_loss:0.7947
#
# EPOCH[101] - STEP[250]
# Generator_loss:1.5098
# L1_loss:0.0789
# Discriminator_loss:0.8894
#
# EPOCH[102] - STEP[50]
# Generator_loss:0.6970
# L1_loss:0.0897
# Discriminator_loss:0.9665
#
# EPOCH[102] - STEP[100]
# Generator_loss:2.0838
# L1_loss:0.0866
# Discriminator_loss:0.6339
#
# EPOCH[102] - STEP[150]
# Generator_loss:2.3285
# L1_loss:0.0869
# Discriminator_loss:0.3027
#
# EPOCH[102] - STEP[200]
# Generator_loss:1.9132
# L1_loss:0.0973
# Discriminator_loss:0.4104
#
# EPOCH[102] - STEP[250]
# Generator_loss:0.8038
# L1_loss:0.0969
# Discriminator_loss:0.8303
#
# EPOCH[103] - STEP[50]
# Generator_loss:2.8371
# L1_loss:0.0928
# Discriminator_loss:0.4442
#
# EPOCH[103] - STEP[100]
# Generator_loss:0.9369
# L1_loss:0.1069
# Discriminator_loss:1.2800
#
# EPOCH[103] - STEP[150]
# Generator_loss:1.6032
# L1_loss:0.0921
# Discriminator_loss:0.4501
#
# EPOCH[103] - STEP[200]
# Generator_loss:5.3633
# L1_loss:0.0921
# Discriminator_loss:0.4329
#
# EPOCH[103] - STEP[250]
# Generator_loss:3.1790
# L1_loss:0.0818
# Discriminator_loss:0.2218
#
# EPOCH[104] - STEP[50]
# Generator_loss:1.3280
# L1_loss:0.0985
# Discriminator_loss:0.5806
#
# EPOCH[104] - STEP[100]
# Generator_loss:1.1492
# L1_loss:0.1080
# Discriminator_loss:0.7212
#
# EPOCH[104] - STEP[150]
# Generator_loss:0.8805
# L1_loss:0.0957
# Discriminator_loss:0.8374
#
# EPOCH[104] - STEP[200]
# Generator_loss:4.0866
# L1_loss:0.0908
# Discriminator_loss:0.2227
#
# EPOCH[104] - STEP[250]
# Generator_loss:1.8864
# L1_loss:0.0923
# Discriminator_loss:0.3374
#
# EPOCH[105] - STEP[50]
# Generator_loss:1.3181
# L1_loss:0.0880
# Discriminator_loss:1.1361
#
# EPOCH[105] - STEP[100]
# Generator_loss:3.0955
# L1_loss:0.0890
# Discriminator_loss:0.4408
#
# EPOCH[105] - STEP[150]
# Generator_loss:3.8007
# L1_loss:0.0851
# Discriminator_loss:1.0515
#
# EPOCH[105] - STEP[200]
# Generator_loss:2.3192
# L1_loss:0.1026
# Discriminator_loss:0.4715
#
# EPOCH[105] - STEP[250]
# Generator_loss:3.3724
# L1_loss:0.0770
# Discriminator_loss:0.8447
#
# EPOCH[106] - STEP[50]
# Generator_loss:2.1019
# L1_loss:0.0909
# Discriminator_loss:0.6646
#
# EPOCH[106] - STEP[100]
# Generator_loss:1.8871
# L1_loss:0.0900
# Discriminator_loss:0.3854
#
# EPOCH[106] - STEP[150]
# Generator_loss:2.3392
# L1_loss:0.0949
# Discriminator_loss:0.6214
#
# EPOCH[106] - STEP[200]
# Generator_loss:1.8147
# L1_loss:0.0892
# Discriminator_loss:0.3927
#
# EPOCH[106] - STEP[250]
# Generator_loss:0.7996
# L1_loss:0.0889
# Discriminator_loss:0.8869
#
# EPOCH[107] - STEP[50]
# Generator_loss:2.2659
# L1_loss:0.0887
# Discriminator_loss:0.3631
#
# EPOCH[107] - STEP[100]
# Generator_loss:3.3202
# L1_loss:0.0890
# Discriminator_loss:0.6839
#
# EPOCH[107] - STEP[150]
# Generator_loss:3.4535
# L1_loss:0.0918
# Discriminator_loss:1.2492
#
# EPOCH[107] - STEP[200]
# Generator_loss:2.6704
# L1_loss:0.0900
# Discriminator_loss:0.4489
#
# EPOCH[107] - STEP[250]
# Generator_loss:2.5002
# L1_loss:0.0828
# Discriminator_loss:0.6922
#
# EPOCH[108] - STEP[50]
# Generator_loss:2.7107
# L1_loss:0.0892
# Discriminator_loss:0.4292
#
# EPOCH[108] - STEP[100]
# Generator_loss:4.0304
# L1_loss:0.0875
# Discriminator_loss:0.4374
#
# EPOCH[108] - STEP[150]
# Generator_loss:2.2578
# L1_loss:0.1027
# Discriminator_loss:0.4329
#
# EPOCH[108] - STEP[200]
# Generator_loss:1.0929
# L1_loss:0.0886
# Discriminator_loss:0.6912
#
# EPOCH[108] - STEP[250]
# Generator_loss:1.5917
# L1_loss:0.1150
# Discriminator_loss:0.4060
#
# EPOCH[109] - STEP[50]
# Generator_loss:1.6306
# L1_loss:0.0961
# Discriminator_loss:0.4011
#
# EPOCH[109] - STEP[100]
# Generator_loss:2.2629
# L1_loss:0.0861
# Discriminator_loss:0.3087
#
# EPOCH[109] - STEP[150]
# Generator_loss:2.8869
# L1_loss:0.1000
# Discriminator_loss:0.6281
#
# EPOCH[109] - STEP[200]
# Generator_loss:2.0705
# L1_loss:0.0969
# Discriminator_loss:0.4617
#
# EPOCH[109] - STEP[250]
# Generator_loss:1.8826
# L1_loss:0.0844
# Discriminator_loss:0.5974
#
# EPOCH[110] - STEP[50]
# Generator_loss:3.6107
# L1_loss:0.0851
# Discriminator_loss:0.3425
#
# EPOCH[110] - STEP[100]
# Generator_loss:2.0842
# L1_loss:0.0885
# Discriminator_loss:0.2806
#
# EPOCH[110] - STEP[150]
# Generator_loss:1.1382
# L1_loss:0.0924
# Discriminator_loss:0.6884
#
# EPOCH[110] - STEP[200]
# Generator_loss:1.4719
# L1_loss:0.0927
# Discriminator_loss:0.4060
#
# EPOCH[110] - STEP[250]
# Generator_loss:1.7675
# L1_loss:0.0945
# Discriminator_loss:0.5098
#
# EPOCH[111] - STEP[50]
# Generator_loss:2.7000
# L1_loss:0.0910
# Discriminator_loss:0.3445
#
# EPOCH[111] - STEP[100]
# Generator_loss:3.2226
# L1_loss:0.0909
# Discriminator_loss:1.5323
#
# EPOCH[111] - STEP[150]
# Generator_loss:3.6672
# L1_loss:0.1121
# Discriminator_loss:0.5506
#
# EPOCH[111] - STEP[200]
# Generator_loss:1.0978
# L1_loss:0.0943
# Discriminator_loss:0.6990
#
# EPOCH[111] - STEP[250]
# Generator_loss:3.1220
# L1_loss:0.1046
# Discriminator_loss:0.4381
#
# EPOCH[112] - STEP[50]
# Generator_loss:1.4294
# L1_loss:0.0922
# Discriminator_loss:0.5151
#
# EPOCH[112] - STEP[100]
# Generator_loss:2.8883
# L1_loss:0.1021
# Discriminator_loss:0.3158
#
# EPOCH[112] - STEP[150]
# Generator_loss:1.8087
# L1_loss:0.0940
# Discriminator_loss:0.3308
#
# EPOCH[112] - STEP[200]
# Generator_loss:1.1498
# L1_loss:0.0882
# Discriminator_loss:0.6759
#
# EPOCH[112] - STEP[250]
# Generator_loss:2.8146
# L1_loss:0.1024
# Discriminator_loss:0.4853
#
# EPOCH[113] - STEP[50]
# Generator_loss:2.4176
# L1_loss:0.0932
# Discriminator_loss:0.3395
#
# EPOCH[113] - STEP[100]
# Generator_loss:2.8183
# L1_loss:0.1058
# Discriminator_loss:0.4207
#
# EPOCH[113] - STEP[150]
# Generator_loss:2.0177
# L1_loss:0.0940
# Discriminator_loss:0.4983
#
# EPOCH[113] - STEP[200]
# Generator_loss:1.5523
# L1_loss:0.0919
# Discriminator_loss:0.5757
#
# EPOCH[113] - STEP[250]
# Generator_loss:2.8901
# L1_loss:0.0974
# Discriminator_loss:0.1535
#
# EPOCH[114] - STEP[50]
# Generator_loss:1.0487
# L1_loss:0.0894
# Discriminator_loss:0.6795
#
# EPOCH[114] - STEP[100]
# Generator_loss:2.3742
# L1_loss:0.0863
# Discriminator_loss:0.2439
#
# EPOCH[114] - STEP[150]
# Generator_loss:2.1983
# L1_loss:0.0927
# Discriminator_loss:0.3517
#
# EPOCH[114] - STEP[200]
# Generator_loss:4.1174
# L1_loss:0.1062
# Discriminator_loss:0.1364
#
# EPOCH[114] - STEP[250]
# Generator_loss:2.6216
# L1_loss:0.0889
# Discriminator_loss:0.1953
#
# EPOCH[115] - STEP[50]
# Generator_loss:1.4734
# L1_loss:0.0843
# Discriminator_loss:0.6043
#
# EPOCH[115] - STEP[100]
# Generator_loss:0.9655
# L1_loss:0.0998
# Discriminator_loss:0.8648
#
# EPOCH[115] - STEP[150]
# Generator_loss:0.9885
# L1_loss:0.0885
# Discriminator_loss:0.7917
#
# EPOCH[115] - STEP[200]
# Generator_loss:3.0742
# L1_loss:0.0925
# Discriminator_loss:0.3877
#
# EPOCH[115] - STEP[250]
# Generator_loss:3.6814
# L1_loss:0.0953
# Discriminator_loss:0.2915
#
# EPOCH[116] - STEP[50]
# Generator_loss:2.5003
# L1_loss:0.0777
# Discriminator_loss:0.7323
#
# EPOCH[116] - STEP[100]
# Generator_loss:3.6056
# L1_loss:0.1003
# Discriminator_loss:0.7189
#
# EPOCH[116] - STEP[150]
# Generator_loss:2.2893
# L1_loss:0.0854
# Discriminator_loss:0.3639
#
# EPOCH[116] - STEP[200]
# Generator_loss:1.4029
# L1_loss:0.0957
# Discriminator_loss:0.5148
#
# EPOCH[116] - STEP[250]
# Generator_loss:3.6103
# L1_loss:0.0904
# Discriminator_loss:0.2554
#
# EPOCH[117] - STEP[50]
# Generator_loss:2.6076
# L1_loss:0.0970
# Discriminator_loss:1.0739
#
# EPOCH[117] - STEP[100]
# Generator_loss:2.4198
# L1_loss:0.0934
# Discriminator_loss:0.4617
#
# EPOCH[117] - STEP[150]
# Generator_loss:3.7991
# L1_loss:0.1052
# Discriminator_loss:0.0953
#
# EPOCH[117] - STEP[200]
# Generator_loss:2.9715
# L1_loss:0.1120
# Discriminator_loss:0.3209
#
# EPOCH[117] - STEP[250]
# Generator_loss:3.3944
# L1_loss:0.0964
# Discriminator_loss:0.1951
#
# EPOCH[118] - STEP[50]
# Generator_loss:1.6322
# L1_loss:0.0990
# Discriminator_loss:0.4664
#
# EPOCH[118] - STEP[100]
# Generator_loss:1.9717
# L1_loss:0.0983
# Discriminator_loss:0.3488
#
# EPOCH[118] - STEP[150]
# Generator_loss:4.4533
# L1_loss:0.0795
# Discriminator_loss:0.1494
#
# EPOCH[118] - STEP[200]
# Generator_loss:2.0040
# L1_loss:0.0932
# Discriminator_loss:0.9426
#
# EPOCH[118] - STEP[250]
# Generator_loss:0.8381
# L1_loss:0.0957
# Discriminator_loss:0.9388
#
# EPOCH[119] - STEP[50]
# Generator_loss:4.5497
# L1_loss:0.0929
# Discriminator_loss:0.2635
#
# EPOCH[119] - STEP[100]
# Generator_loss:3.3290
# L1_loss:0.1014
# Discriminator_loss:0.8870
#
# EPOCH[119] - STEP[150]
# Generator_loss:2.9036
# L1_loss:0.1097
# Discriminator_loss:0.3015
#
# EPOCH[119] - STEP[200]
# Generator_loss:2.7012
# L1_loss:0.0956
# Discriminator_loss:0.2841
#
# EPOCH[119] - STEP[250]
# Generator_loss:3.2275
# L1_loss:0.0866
# Discriminator_loss:0.6270
#
# EPOCH[120] - STEP[50]
# Generator_loss:3.1064
# L1_loss:0.0973
# Discriminator_loss:0.1491
#
# EPOCH[120] - STEP[100]
# Generator_loss:1.3774
# L1_loss:0.0928
# Discriminator_loss:0.6699
#
# EPOCH[120] - STEP[150]
# Generator_loss:1.2594
# L1_loss:0.1073
# Discriminator_loss:0.5393
#
# EPOCH[120] - STEP[200]
# Generator_loss:3.9733
# L1_loss:0.0956
# Discriminator_loss:0.4248
#
# EPOCH[120] - STEP[250]
# Generator_loss:3.3123
# L1_loss:0.1089
# Discriminator_loss:0.1685
#
# EPOCH[121] - STEP[50]
# Generator_loss:0.8004
# L1_loss:0.0820
# Discriminator_loss:0.9180
#
# EPOCH[121] - STEP[100]
# Generator_loss:3.4353
# L1_loss:0.0898
# Discriminator_loss:0.3179
#
# EPOCH[121] - STEP[150]
# Generator_loss:2.6407
# L1_loss:0.0949
# Discriminator_loss:0.5706
#
# EPOCH[121] - STEP[200]
# Generator_loss:2.5075
# L1_loss:0.0932
# Discriminator_loss:0.4926
#
# EPOCH[121] - STEP[250]
# Generator_loss:2.9645
# L1_loss:0.0982
# Discriminator_loss:0.2161
#
# EPOCH[122] - STEP[50]
# Generator_loss:1.9191
# L1_loss:0.0973
# Discriminator_loss:0.2838
#
# EPOCH[122] - STEP[100]
# Generator_loss:4.3200
# L1_loss:0.0965
# Discriminator_loss:0.7215
#
# EPOCH[122] - STEP[150]
# Generator_loss:2.0523
# L1_loss:0.1027
# Discriminator_loss:0.3205
#
# EPOCH[122] - STEP[200]
# Generator_loss:2.8929
# L1_loss:0.1075
# Discriminator_loss:0.4318
#
# EPOCH[122] - STEP[250]
# Generator_loss:2.0250
# L1_loss:0.0906
# Discriminator_loss:0.3018
#
# EPOCH[123] - STEP[50]
# Generator_loss:2.7595
# L1_loss:0.1009
# Discriminator_loss:0.3739
#
# EPOCH[123] - STEP[100]
# Generator_loss:2.1952
# L1_loss:0.0866
# Discriminator_loss:0.3361
#
# EPOCH[123] - STEP[150]
# Generator_loss:1.7902
# L1_loss:0.0884
# Discriminator_loss:0.6516
#
# EPOCH[123] - STEP[200]
# Generator_loss:2.4142
# L1_loss:0.0894
# Discriminator_loss:0.2562
#
# EPOCH[123] - STEP[250]
# Generator_loss:4.8785
# L1_loss:0.0941
# Discriminator_loss:0.7082
#
# EPOCH[124] - STEP[50]
# Generator_loss:2.3081
# L1_loss:0.0930
# Discriminator_loss:0.3380
#
# EPOCH[124] - STEP[100]
# Generator_loss:3.8407
# L1_loss:0.0959
# Discriminator_loss:0.4242
#
# EPOCH[124] - STEP[150]
# Generator_loss:3.8891
# L1_loss:0.0861
# Discriminator_loss:0.4924
#
# EPOCH[124] - STEP[200]
# Generator_loss:1.2922
# L1_loss:0.1066
# Discriminator_loss:0.6107
#
# EPOCH[124] - STEP[250]
# Generator_loss:1.6304
# L1_loss:0.1003
# Discriminator_loss:0.7296
#
# EPOCH[125] - STEP[50]
# Generator_loss:2.1319
# L1_loss:0.1018
# Discriminator_loss:0.3955
#
# EPOCH[125] - STEP[100]
# Generator_loss:1.8549
# L1_loss:0.0913
# Discriminator_loss:0.5052
#
# EPOCH[125] - STEP[150]
# Generator_loss:2.6993
# L1_loss:0.0823
# Discriminator_loss:0.3554
#
# EPOCH[125] - STEP[200]
# Generator_loss:1.6918
# L1_loss:0.0928
# Discriminator_loss:0.3748
#
# EPOCH[125] - STEP[250]
# Generator_loss:2.1340
# L1_loss:0.0976
# Discriminator_loss:0.3194
#
# EPOCH[126] - STEP[50]
# Generator_loss:3.0154
# L1_loss:0.0866
# Discriminator_loss:0.2039
#
# EPOCH[126] - STEP[100]
# Generator_loss:2.9640
# L1_loss:0.0889
# Discriminator_loss:0.3576
#
# EPOCH[126] - STEP[150]
# Generator_loss:2.1638
# L1_loss:0.0921
# Discriminator_loss:0.2773
#
# EPOCH[126] - STEP[200]
# Generator_loss:3.2887
# L1_loss:0.1005
# Discriminator_loss:0.2252
#
# EPOCH[126] - STEP[250]
# Generator_loss:1.0732
# L1_loss:0.0953
# Discriminator_loss:0.8024
#
# EPOCH[127] - STEP[50]
# Generator_loss:1.9078
# L1_loss:0.0887
# Discriminator_loss:0.3121
#
# EPOCH[127] - STEP[100]
# Generator_loss:5.0586
# L1_loss:0.0943
# Discriminator_loss:1.0776
#
# EPOCH[127] - STEP[150]
# Generator_loss:5.9713
# L1_loss:0.0953
# Discriminator_loss:1.1587
#
# EPOCH[127] - STEP[200]
# Generator_loss:1.5948
# L1_loss:0.0980
# Discriminator_loss:0.4241
#
# EPOCH[127] - STEP[250]
# Generator_loss:3.9674
# L1_loss:0.0822
# Discriminator_loss:0.3629
#
# EPOCH[128] - STEP[50]
# Generator_loss:2.8102
# L1_loss:0.0886
# Discriminator_loss:0.7459
#
# EPOCH[128] - STEP[100]
# Generator_loss:3.5411
# L1_loss:0.0908
# Discriminator_loss:0.2136
#
# EPOCH[128] - STEP[150]
# Generator_loss:3.1580
# L1_loss:0.1066
# Discriminator_loss:0.6520
#
# EPOCH[128] - STEP[200]
# Generator_loss:1.0562
# L1_loss:0.1148
# Discriminator_loss:0.8053
#
# EPOCH[128] - STEP[250]
# Generator_loss:5.7170
# L1_loss:0.0814
# Discriminator_loss:1.9365
#
# EPOCH[129] - STEP[50]
# Generator_loss:2.9928
# L1_loss:0.1037
# Discriminator_loss:0.3437
#
# EPOCH[129] - STEP[100]
# Generator_loss:2.6095
# L1_loss:0.0905
# Discriminator_loss:0.2420
#
# EPOCH[129] - STEP[150]
# Generator_loss:2.5839
# L1_loss:0.0996
# Discriminator_loss:0.3216
#
# EPOCH[129] - STEP[200]
# Generator_loss:1.5506
# L1_loss:0.1072
# Discriminator_loss:0.4631
#
# EPOCH[129] - STEP[250]
# Generator_loss:2.9017
# L1_loss:0.1007
# Discriminator_loss:0.1738
#
# EPOCH[130] - STEP[50]
# Generator_loss:2.2948
# L1_loss:0.0947
# Discriminator_loss:0.4366
#
# EPOCH[130] - STEP[100]
# Generator_loss:1.7445
# L1_loss:0.0980
# Discriminator_loss:0.3499
#
# EPOCH[130] - STEP[150]
# Generator_loss:2.8333
# L1_loss:0.0915
# Discriminator_loss:0.4080
#
# EPOCH[130] - STEP[200]
# Generator_loss:2.5748
# L1_loss:0.0892
# Discriminator_loss:0.4351
#
# EPOCH[130] - STEP[250]
# Generator_loss:2.3713
# L1_loss:0.1114
# Discriminator_loss:0.5052
#
# EPOCH[131] - STEP[50]
# Generator_loss:2.0966
# L1_loss:0.0845
# Discriminator_loss:0.9612
#
# EPOCH[131] - STEP[100]
# Generator_loss:2.5076
# L1_loss:0.0986
# Discriminator_loss:0.4137
#
# EPOCH[131] - STEP[150]
# Generator_loss:2.8576
# L1_loss:0.0891
# Discriminator_loss:0.7490
#
# EPOCH[131] - STEP[200]
# Generator_loss:3.1091
# L1_loss:0.0968
# Discriminator_loss:0.1863
#
# EPOCH[131] - STEP[250]
# Generator_loss:1.8314
# L1_loss:0.0869
# Discriminator_loss:0.4021
#
# EPOCH[132] - STEP[50]
# Generator_loss:2.9618
# L1_loss:0.1036
# Discriminator_loss:0.1834
#
# EPOCH[132] - STEP[100]
# Generator_loss:2.1338
# L1_loss:0.0988
# Discriminator_loss:0.3321
#
# EPOCH[132] - STEP[150]
# Generator_loss:3.0047
# L1_loss:0.0938
# Discriminator_loss:0.2850
#
# EPOCH[132] - STEP[200]
# Generator_loss:2.8806
# L1_loss:0.0968
# Discriminator_loss:0.4198
#
# EPOCH[132] - STEP[250]
# Generator_loss:4.5781
# L1_loss:0.0890
# Discriminator_loss:0.4060
#
# EPOCH[133] - STEP[50]
# Generator_loss:4.1577
# L1_loss:0.0817
# Discriminator_loss:1.0799
#
# EPOCH[133] - STEP[100]
# Generator_loss:4.7368
# L1_loss:0.0805
# Discriminator_loss:0.5478
#
# EPOCH[133] - STEP[150]
# Generator_loss:2.1669
# L1_loss:0.1118
# Discriminator_loss:0.3478
#
# EPOCH[133] - STEP[200]
# Generator_loss:3.0025
# L1_loss:0.0961
# Discriminator_loss:0.6275
#
# EPOCH[133] - STEP[250]
# Generator_loss:2.2891
# L1_loss:0.0870
# Discriminator_loss:0.4231
#
# EPOCH[134] - STEP[50]
# Generator_loss:2.2237
# L1_loss:0.1034
# Discriminator_loss:0.3117
#
# EPOCH[134] - STEP[100]
# Generator_loss:4.1059
# L1_loss:0.1022
# Discriminator_loss:0.1214
#
# EPOCH[134] - STEP[150]
# Generator_loss:2.4490
# L1_loss:0.1056
# Discriminator_loss:0.4210
#
# EPOCH[134] - STEP[200]
# Generator_loss:3.5756
# L1_loss:0.0940
# Discriminator_loss:0.3550
#
# EPOCH[134] - STEP[250]
# Generator_loss:2.0677
# L1_loss:0.0869
# Discriminator_loss:0.5653
#
# EPOCH[135] - STEP[50]
# Generator_loss:1.1577
# L1_loss:0.0840
# Discriminator_loss:0.9951
#
# EPOCH[135] - STEP[100]
# Generator_loss:0.8079
# L1_loss:0.0905
# Discriminator_loss:0.9527
#
# EPOCH[135] - STEP[150]
# Generator_loss:2.8450
# L1_loss:0.0889
# Discriminator_loss:0.3242
#
# EPOCH[135] - STEP[200]
# Generator_loss:1.2060
# L1_loss:0.0963
# Discriminator_loss:0.5900
#
# EPOCH[135] - STEP[250]
# Generator_loss:2.4890
# L1_loss:0.0889
# Discriminator_loss:0.4261
#
# EPOCH[136] - STEP[50]
# Generator_loss:2.2578
# L1_loss:0.1061
# Discriminator_loss:0.5279
#
# EPOCH[136] - STEP[100]
# Generator_loss:1.0771
# L1_loss:0.0904
# Discriminator_loss:0.7191
#
# EPOCH[136] - STEP[150]
# Generator_loss:4.3359
# L1_loss:0.0886
# Discriminator_loss:1.3215
#
# EPOCH[136] - STEP[200]
# Generator_loss:4.7060
# L1_loss:0.0918
# Discriminator_loss:0.4559
#
# EPOCH[136] - STEP[250]
# Generator_loss:1.5867
# L1_loss:0.0889
# Discriminator_loss:0.4121
#
# EPOCH[137] - STEP[50]
# Generator_loss:2.9926
# L1_loss:0.1020
# Discriminator_loss:0.1677
#
# EPOCH[137] - STEP[100]
# Generator_loss:2.9022
# L1_loss:0.0864
# Discriminator_loss:0.3537
#
# EPOCH[137] - STEP[150]
# Generator_loss:3.5284
# L1_loss:0.0952
# Discriminator_loss:0.6514
#
# EPOCH[137] - STEP[200]
# Generator_loss:3.3405
# L1_loss:0.0984
# Discriminator_loss:0.2803
#
# EPOCH[137] - STEP[250]
# Generator_loss:0.7061
# L1_loss:0.0977
# Discriminator_loss:1.1409
#
# EPOCH[138] - STEP[50]
# Generator_loss:2.4602
# L1_loss:0.0897
# Discriminator_loss:0.4304
#
# EPOCH[138] - STEP[100]
# Generator_loss:0.9430
# L1_loss:0.0837
# Discriminator_loss:0.8074
#
# EPOCH[138] - STEP[150]
# Generator_loss:4.9594
# L1_loss:0.0799
# Discriminator_loss:1.1983
#
# EPOCH[138] - STEP[200]
# Generator_loss:2.2882
# L1_loss:0.0966
# Discriminator_loss:0.3392
#
# EPOCH[138] - STEP[250]
# Generator_loss:3.5768
# L1_loss:0.0879
# Discriminator_loss:0.1410
#
# EPOCH[139] - STEP[50]
# Generator_loss:3.6183
# L1_loss:0.0957
# Discriminator_loss:0.1785
#
# EPOCH[139] - STEP[100]
# Generator_loss:1.4051
# L1_loss:0.0912
# Discriminator_loss:0.5612
#
# EPOCH[139] - STEP[150]
# Generator_loss:4.1156
# L1_loss:0.0853
# Discriminator_loss:0.3907
#
# EPOCH[139] - STEP[200]
# Generator_loss:2.0256
# L1_loss:0.1007
# Discriminator_loss:0.4253
#
# EPOCH[139] - STEP[250]
# Generator_loss:1.8172
# L1_loss:0.0860
# Discriminator_loss:0.3825
#
# EPOCH[140] - STEP[50]
# Generator_loss:1.8899
# L1_loss:0.0973
# Discriminator_loss:0.3769
#
# EPOCH[140] - STEP[100]
# Generator_loss:4.4872
# L1_loss:0.1093
# Discriminator_loss:0.2446
#
# EPOCH[140] - STEP[150]
# Generator_loss:3.7925
# L1_loss:0.0925
# Discriminator_loss:0.5102
#
# EPOCH[140] - STEP[200]
# Generator_loss:1.9591
# L1_loss:0.1014
# Discriminator_loss:0.3103
#
# EPOCH[140] - STEP[250]
# Generator_loss:0.6165
# L1_loss:0.0975
# Discriminator_loss:1.3994
#
# EPOCH[141] - STEP[50]
# Generator_loss:3.0759
# L1_loss:0.0917
# Discriminator_loss:0.2811
#
# EPOCH[141] - STEP[100]
# Generator_loss:5.0401
# L1_loss:0.0894
# Discriminator_loss:0.1754
#
# EPOCH[141] - STEP[150]
# Generator_loss:2.9817
# L1_loss:0.0982
# Discriminator_loss:0.3170
#
# EPOCH[141] - STEP[200]
# Generator_loss:4.4196
# L1_loss:0.0913
# Discriminator_loss:0.8417
#
# EPOCH[141] - STEP[250]
# Generator_loss:1.4606
# L1_loss:0.0868
# Discriminator_loss:0.9177
#
# EPOCH[142] - STEP[50]
# Generator_loss:2.5565
# L1_loss:0.0836
# Discriminator_loss:0.3515
#
# EPOCH[142] - STEP[100]
# Generator_loss:3.0498
# L1_loss:0.0945
# Discriminator_loss:0.3295
#
# EPOCH[142] - STEP[150]
# Generator_loss:5.7417
# L1_loss:0.0922
# Discriminator_loss:0.5559
#
# EPOCH[142] - STEP[200]
# Generator_loss:2.6331
# L1_loss:0.0878
# Discriminator_loss:0.2733
#
# EPOCH[142] - STEP[250]
# Generator_loss:3.4554
# L1_loss:0.0846
# Discriminator_loss:0.3560
#
# EPOCH[143] - STEP[50]
# Generator_loss:1.1132
# L1_loss:0.1003
# Discriminator_loss:0.6449
#
# EPOCH[143] - STEP[100]
# Generator_loss:1.1588
# L1_loss:0.0928
# Discriminator_loss:0.6140
#
# EPOCH[143] - STEP[150]
# Generator_loss:1.6096
# L1_loss:0.0797
# Discriminator_loss:0.4475
#
# EPOCH[143] - STEP[200]
# Generator_loss:2.4351
# L1_loss:0.1004
# Discriminator_loss:0.2445
#
# EPOCH[143] - STEP[250]
# Generator_loss:4.7065
# L1_loss:0.0825
# Discriminator_loss:0.3730
#
# EPOCH[144] - STEP[50]
# Generator_loss:1.3257
# L1_loss:0.0920
# Discriminator_loss:0.6485
#
# EPOCH[144] - STEP[100]
# Generator_loss:1.9225
# L1_loss:0.1023
# Discriminator_loss:0.3497
#
# EPOCH[144] - STEP[150]
# Generator_loss:3.2520
# L1_loss:0.0834
# Discriminator_loss:0.2936
#
# EPOCH[144] - STEP[200]
# Generator_loss:2.8503
# L1_loss:0.0962
# Discriminator_loss:0.2660
#
# EPOCH[144] - STEP[250]
# Generator_loss:4.1842
# L1_loss:0.0922
# Discriminator_loss:0.1604
#
# EPOCH[145] - STEP[50]
# Generator_loss:1.6261
# L1_loss:0.0883
# Discriminator_loss:0.4292
#
# EPOCH[145] - STEP[100]
# Generator_loss:2.2746
# L1_loss:0.1102
# Discriminator_loss:0.2746
#
# EPOCH[145] - STEP[150]
# Generator_loss:4.4904
# L1_loss:0.0964
# Discriminator_loss:0.2925
#
# EPOCH[145] - STEP[200]
# Generator_loss:1.4498
# L1_loss:0.0907
# Discriminator_loss:0.4873
#
# EPOCH[145] - STEP[250]
# Generator_loss:0.7344
# L1_loss:0.1006
# Discriminator_loss:1.4717
#
# EPOCH[146] - STEP[50]
# Generator_loss:2.0658
# L1_loss:0.0849
# Discriminator_loss:0.3502
#
# EPOCH[146] - STEP[100]
# Generator_loss:3.2208
# L1_loss:0.0896
# Discriminator_loss:0.3014
#
# EPOCH[146] - STEP[150]
# Generator_loss:1.6846
# L1_loss:0.0863
# Discriminator_loss:0.4502
#
# EPOCH[146] - STEP[200]
# Generator_loss:5.0408
# L1_loss:0.0943
# Discriminator_loss:0.3935
#
# EPOCH[146] - STEP[250]
# Generator_loss:3.4485
# L1_loss:0.1039
# Discriminator_loss:0.3671
#
# EPOCH[147] - STEP[50]
# Generator_loss:4.2269
# L1_loss:0.0866
# Discriminator_loss:0.3354
#
# EPOCH[147] - STEP[100]
# Generator_loss:2.4401
# L1_loss:0.0956
# Discriminator_loss:0.3561
#
# EPOCH[147] - STEP[150]
# Generator_loss:5.2399
# L1_loss:0.0861
# Discriminator_loss:1.2367
#
# EPOCH[147] - STEP[200]
# Generator_loss:2.2796
# L1_loss:0.1066
# Discriminator_loss:0.3503
#
# EPOCH[147] - STEP[250]
# Generator_loss:3.2975
# L1_loss:0.0999
# Discriminator_loss:0.3483
#
# EPOCH[148] - STEP[50]
# Generator_loss:1.9978
# L1_loss:0.1003
# Discriminator_loss:0.7297
#
# EPOCH[148] - STEP[100]
# Generator_loss:3.3347
# L1_loss:0.0901
# Discriminator_loss:0.3634
#
# EPOCH[148] - STEP[150]
# Generator_loss:2.5416
# L1_loss:0.0905
# Discriminator_loss:0.3356
#
# EPOCH[148] - STEP[200]
# Generator_loss:2.0856
# L1_loss:0.1008
# Discriminator_loss:0.3144
#
# EPOCH[148] - STEP[250]
# Generator_loss:1.8937
# L1_loss:0.1036
# Discriminator_loss:0.4190
#
# EPOCH[149] - STEP[50]
# Generator_loss:2.3752
# L1_loss:0.0794
# Discriminator_loss:0.3425
#
# EPOCH[149] - STEP[100]
# Generator_loss:1.2325
# L1_loss:0.0924
# Discriminator_loss:0.7411
#
# EPOCH[149] - STEP[150]
# Generator_loss:4.0808
# L1_loss:0.0889
# Discriminator_loss:0.3940
#
# EPOCH[149] - STEP[200]
# Generator_loss:1.3840
# L1_loss:0.1003
# Discriminator_loss:0.6767
#
# EPOCH[149] - STEP[250]
# Generator_loss:4.7228
# L1_loss:0.0894
# Discriminator_loss:0.4740
#
# EPOCH[150] - STEP[50]
# Generator_loss:3.7249
# L1_loss:0.0948
# Discriminator_loss:1.6643
#
# EPOCH[150] - STEP[100]
# Generator_loss:1.5131
# L1_loss:0.0954
# Discriminator_loss:0.4986
#
# EPOCH[150] - STEP[150]
# Generator_loss:3.8673
# L1_loss:0.0970
# Discriminator_loss:0.2336
#
# EPOCH[150] - STEP[200]
# Generator_loss:3.0363
# L1_loss:0.0940
# Discriminator_loss:0.2858
#
# EPOCH[150] - STEP[250]
# Generator_loss:4.3681
# L1_loss:0.0884
# Discriminator_loss:0.1206
#
# EPOCH[151] - STEP[50]
# Generator_loss:2.3592
# L1_loss:0.0882
# Discriminator_loss:0.3164
#
# EPOCH[151] - STEP[100]
# Generator_loss:4.4180
# L1_loss:0.0782
# Discriminator_loss:0.8006
#
# EPOCH[151] - STEP[150]
# Generator_loss:0.9266
# L1_loss:0.0951
# Discriminator_loss:0.8671
#
# EPOCH[151] - STEP[200]
# Generator_loss:2.3810
# L1_loss:0.0854
# Discriminator_loss:0.3211
#
# EPOCH[151] - STEP[250]
# Generator_loss:2.3403
# L1_loss:0.1053
# Discriminator_loss:0.2603
#
# EPOCH[152] - STEP[50]
# Generator_loss:1.3462
# L1_loss:0.0861
# Discriminator_loss:0.8032
#
# EPOCH[152] - STEP[100]
# Generator_loss:1.9967
# L1_loss:0.0867
# Discriminator_loss:0.6431
#
# EPOCH[152] - STEP[150]
# Generator_loss:3.1114
# L1_loss:0.1038
# Discriminator_loss:0.2054
#
# EPOCH[152] - STEP[200]
# Generator_loss:3.7438
# L1_loss:0.0848
# Discriminator_loss:0.2861
#
# EPOCH[152] - STEP[250]
# Generator_loss:3.8656
# L1_loss:0.1011
# Discriminator_loss:0.3716
#
# EPOCH[153] - STEP[50]
# Generator_loss:4.0974
# L1_loss:0.1005
# Discriminator_loss:0.4626
#
# EPOCH[153] - STEP[100]
# Generator_loss:3.5394
# L1_loss:0.0842
# Discriminator_loss:0.3820
#
# EPOCH[153] - STEP[150]
# Generator_loss:3.0062
# L1_loss:0.0900
# Discriminator_loss:0.3341
#
# EPOCH[153] - STEP[200]
# Generator_loss:4.0207
# L1_loss:0.0970
# Discriminator_loss:0.5444
#
# EPOCH[153] - STEP[250]
# Generator_loss:2.9436
# L1_loss:0.1054
# Discriminator_loss:0.3832
#
# EPOCH[154] - STEP[50]
# Generator_loss:1.5389
# L1_loss:0.0862
# Discriminator_loss:0.6011
#
# EPOCH[154] - STEP[100]
# Generator_loss:2.8485
# L1_loss:0.0911
# Discriminator_loss:0.4240
#
# EPOCH[154] - STEP[150]
# Generator_loss:3.7992
# L1_loss:0.0857
# Discriminator_loss:0.4179
#
# EPOCH[154] - STEP[200]
# Generator_loss:3.2835
# L1_loss:0.0869
# Discriminator_loss:0.5677
#
# EPOCH[154] - STEP[250]
# Generator_loss:2.7559
# L1_loss:0.1024
# Discriminator_loss:0.2784
#
# EPOCH[155] - STEP[50]
# Generator_loss:1.5267
# L1_loss:0.0799
# Discriminator_loss:0.6217
#
# EPOCH[155] - STEP[100]
# Generator_loss:4.7211
# L1_loss:0.1065
# Discriminator_loss:0.1802
#
# EPOCH[155] - STEP[150]
# Generator_loss:4.9513
# L1_loss:0.0913
# Discriminator_loss:0.8374
#
# EPOCH[155] - STEP[200]
# Generator_loss:2.2427
# L1_loss:0.0933
# Discriminator_loss:0.2924
#
# EPOCH[155] - STEP[250]
# Generator_loss:1.8475
# L1_loss:0.0856
# Discriminator_loss:0.8040
#
# EPOCH[156] - STEP[50]
# Generator_loss:1.9637
# L1_loss:0.0821
# Discriminator_loss:0.8269
#
# EPOCH[156] - STEP[100]
# Generator_loss:2.5272
# L1_loss:0.0934
# Discriminator_loss:0.2948
#
# EPOCH[156] - STEP[150]
# Generator_loss:3.8350
# L1_loss:0.1023
# Discriminator_loss:0.4826
#
# EPOCH[156] - STEP[200]
# Generator_loss:3.4108
# L1_loss:0.0819
# Discriminator_loss:0.4129
#
# EPOCH[156] - STEP[250]
# Generator_loss:2.9289
# L1_loss:0.1009
# Discriminator_loss:0.5643
#
# EPOCH[157] - STEP[50]
# Generator_loss:3.9492
# L1_loss:0.0928
# Discriminator_loss:0.2147
#
# EPOCH[157] - STEP[100]
# Generator_loss:1.0389
# L1_loss:0.0982
# Discriminator_loss:0.8684
#
# EPOCH[157] - STEP[150]
# Generator_loss:2.9344
# L1_loss:0.0933
# Discriminator_loss:0.2334
#
# EPOCH[157] - STEP[200]
# Generator_loss:1.8926
# L1_loss:0.1035
# Discriminator_loss:0.3752
#
# EPOCH[157] - STEP[250]
# Generator_loss:2.8466
# L1_loss:0.0907
# Discriminator_loss:0.2830
#
# EPOCH[158] - STEP[50]
# Generator_loss:2.1472
# L1_loss:0.0991
# Discriminator_loss:0.2397
#
# EPOCH[158] - STEP[100]
# Generator_loss:2.3756
# L1_loss:0.0881
# Discriminator_loss:0.2397
#
# EPOCH[158] - STEP[150]
# Generator_loss:2.8128
# L1_loss:0.0912
# Discriminator_loss:0.3311
#
# EPOCH[158] - STEP[200]
# Generator_loss:3.9796
# L1_loss:0.0942
# Discriminator_loss:0.2515
#
# EPOCH[158] - STEP[250]
# Generator_loss:2.1641
# L1_loss:0.0884
# Discriminator_loss:0.3542
#
# EPOCH[159] - STEP[50]
# Generator_loss:2.9096
# L1_loss:0.0940
# Discriminator_loss:0.1413
#
# EPOCH[159] - STEP[100]
# Generator_loss:2.3430
# L1_loss:0.0915
# Discriminator_loss:0.4642
#
# EPOCH[159] - STEP[150]
# Generator_loss:2.6050
# L1_loss:0.0934
# Discriminator_loss:0.1961
#
# EPOCH[159] - STEP[200]
# Generator_loss:1.7079
# L1_loss:0.0965
# Discriminator_loss:0.5745
#
# EPOCH[159] - STEP[250]
# Generator_loss:3.1481
# L1_loss:0.0964
# Discriminator_loss:0.7506
#
# EPOCH[160] - STEP[50]
# Generator_loss:3.6945
# L1_loss:0.1016
# Discriminator_loss:0.6145
#
# EPOCH[160] - STEP[100]
# Generator_loss:2.7536
# L1_loss:0.1034
# Discriminator_loss:0.2801
#
# EPOCH[160] - STEP[150]
# Generator_loss:5.3285
# L1_loss:0.0764
# Discriminator_loss:0.1499
#
# EPOCH[160] - STEP[200]
# Generator_loss:1.8515
# L1_loss:0.0844
# Discriminator_loss:0.3293
#
# EPOCH[160] - STEP[250]
# Generator_loss:5.0909
# L1_loss:0.0883
# Discriminator_loss:0.8352
#
# EPOCH[161] - STEP[50]
# Generator_loss:2.0370
# L1_loss:0.0975
# Discriminator_loss:0.3946
#
# EPOCH[161] - STEP[100]
# Generator_loss:4.2288
# L1_loss:0.0985
# Discriminator_loss:0.1620
#
# EPOCH[161] - STEP[150]
# Generator_loss:1.2269
# L1_loss:0.0861
# Discriminator_loss:0.5642
#
# EPOCH[161] - STEP[200]
# Generator_loss:5.6129
# L1_loss:0.0896
# Discriminator_loss:0.6742
#
# EPOCH[161] - STEP[250]
# Generator_loss:4.1893
# L1_loss:0.0838
# Discriminator_loss:0.6353
#
# EPOCH[162] - STEP[50]
# Generator_loss:2.3213
# L1_loss:0.0841
# Discriminator_loss:1.0027
#
# EPOCH[162] - STEP[100]
# Generator_loss:1.7461
# L1_loss:0.0885
# Discriminator_loss:0.3706
#
# EPOCH[162] - STEP[150]
# Generator_loss:2.7062
# L1_loss:0.1036
# Discriminator_loss:0.4024
#
# EPOCH[162] - STEP[200]
# Generator_loss:2.5316
# L1_loss:0.0829
# Discriminator_loss:0.3679
#
# EPOCH[162] - STEP[250]
# Generator_loss:4.3255
# L1_loss:0.0919
# Discriminator_loss:0.5407
#
# EPOCH[163] - STEP[50]
# Generator_loss:4.2428
# L1_loss:0.0882
# Discriminator_loss:0.8103
#
# EPOCH[163] - STEP[100]
# Generator_loss:0.8111
# L1_loss:0.0880
# Discriminator_loss:1.0894
#
# EPOCH[163] - STEP[150]
# Generator_loss:2.0586
# L1_loss:0.0965
# Discriminator_loss:0.5241
#
# EPOCH[163] - STEP[200]
# Generator_loss:2.3633
# L1_loss:0.0838
# Discriminator_loss:0.2451
#
# EPOCH[163] - STEP[250]
# Generator_loss:1.5560
# L1_loss:0.0964
# Discriminator_loss:0.4075
#
# EPOCH[164] - STEP[50]
# Generator_loss:2.3179
# L1_loss:0.0844
# Discriminator_loss:0.3219
#
# EPOCH[164] - STEP[100]
# Generator_loss:4.3367
# L1_loss:0.0928
# Discriminator_loss:0.2997
#
# EPOCH[164] - STEP[150]
# Generator_loss:3.1451
# L1_loss:0.0817
# Discriminator_loss:0.4931
#
# EPOCH[164] - STEP[200]
# Generator_loss:5.4839
# L1_loss:0.0920
# Discriminator_loss:0.9637
#
# EPOCH[164] - STEP[250]
# Generator_loss:3.7975
# L1_loss:0.0892
# Discriminator_loss:0.2419
#
# ...
# Generator_loss:4.8216
# L1_loss:0.0844
# Discriminator_loss:0.1506
#
# EPOCH[279] - STEP[250]
# Generator_loss:1.5361
# L1_loss:0.0796
# Discriminator_loss:0.5614
#
# EPOCH[280] - STEP[50]
# Generator_loss:4.4041
# L1_loss:0.0780
# Discriminator_loss:0.4608
#
# EPOCH[280] - STEP[100]
# Generator_loss:2.9702
# L1_loss:0.0819
# Discriminator_loss:0.1609
#
# EPOCH[280] - STEP[150]
# Generator_loss:3.8790
# L1_loss:0.0909
# Discriminator_loss:0.2031
#
# EPOCH[280] - STEP[200]
# Generator_loss:2.8082
# L1_loss:0.0721
# Discriminator_loss:0.4391
#
# EPOCH[280] - STEP[250]
# Generator_loss:5.0498
# L1_loss:0.0863
# Discriminator_loss:0.1437
#
# EPOCH[281] - STEP[50]
# Generator_loss:4.7350
# L1_loss:0.0925
# Discriminator_loss:0.1291
#
# EPOCH[281] - STEP[100]
# Generator_loss:3.5089
# L1_loss:0.0703
# Discriminator_loss:0.5028
#
# EPOCH[281] - STEP[150]
# Generator_loss:1.3220
# L1_loss:0.0784
# Discriminator_loss:0.5659
#
# EPOCH[281] - STEP[200]
# Generator_loss:4.0519
# L1_loss:0.0916
# Discriminator_loss:0.2594
#
# EPOCH[281] - STEP[250]
# Generator_loss:5.8080
# L1_loss:0.0990
# Discriminator_loss:0.0578
#
# EPOCH[282] - STEP[50]
# Generator_loss:6.0325
# L1_loss:0.0942
# Discriminator_loss:0.1204
#
# EPOCH[282] - STEP[100]
# Generator_loss:2.1636
# L1_loss:0.0847
# Discriminator_loss:0.4484
#
# EPOCH[282] - STEP[150]
# Generator_loss:3.4559
# L1_loss:0.0895
# Discriminator_loss:0.1307
#
# EPOCH[282] - STEP[200]
# Generator_loss:1.9218
# L1_loss:0.0820
# Discriminator_loss:0.5643
#
# EPOCH[282] - STEP[250]
# Generator_loss:2.1219
# L1_loss:0.0724
# Discriminator_loss:0.3375
#
# EPOCH[283] - STEP[50]
# Generator_loss:2.4769
# L1_loss:0.0752
# Discriminator_loss:0.3094
#
# EPOCH[283] - STEP[100]
# Generator_loss:1.6120
# L1_loss:0.0868
# Discriminator_loss:0.5753
#
# EPOCH[283] - STEP[150]
# Generator_loss:3.0986
# L1_loss:0.0800
# Discriminator_loss:0.1954
#
# EPOCH[283] - STEP[200]
# Generator_loss:1.5076
# L1_loss:0.0777
# Discriminator_loss:0.4618
#
# EPOCH[283] - STEP[250]
# Generator_loss:2.1415
# L1_loss:0.0810
# Discriminator_loss:0.3345
#
# EPOCH[284] - STEP[50]
# Generator_loss:1.4078
# L1_loss:0.0904
# Discriminator_loss:0.8904
#
# EPOCH[284] - STEP[100]
# Generator_loss:3.4887
# L1_loss:0.1015
# Discriminator_loss:0.1725
#
# EPOCH[284] - STEP[150]
# Generator_loss:3.4784
# L1_loss:0.0693
# Discriminator_loss:0.1653
#
# EPOCH[284] - STEP[200]
# Generator_loss:4.3038
# L1_loss:0.0892
# Discriminator_loss:0.2287
#
# EPOCH[284] - STEP[250]
# Generator_loss:3.7690
# L1_loss:0.0813
# Discriminator_loss:0.1329
#
# EPOCH[285] - STEP[50]
# Generator_loss:2.7870
# L1_loss:0.0826
# Discriminator_loss:0.2509
#
# EPOCH[285] - STEP[100]
# Generator_loss:3.6311
# L1_loss:0.0803
# Discriminator_loss:0.4483
#
# EPOCH[285] - STEP[150]
# Generator_loss:1.2660
# L1_loss:0.0842
# Discriminator_loss:0.9515
#
# EPOCH[285] - STEP[200]
# Generator_loss:2.0490
# L1_loss:0.0874
# Discriminator_loss:0.5264
#
# EPOCH[285] - STEP[250]
# Generator_loss:2.5263
# L1_loss:0.0862
# Discriminator_loss:0.2098
#
# EPOCH[286] - STEP[50]
# Generator_loss:1.8324
# L1_loss:0.0776
# Discriminator_loss:0.4053
#
# EPOCH[286] - STEP[100]
# Generator_loss:3.6113
# L1_loss:0.0854
# Discriminator_loss:0.1597
#
# EPOCH[286] - STEP[150]
# Generator_loss:2.4831
# L1_loss:0.0805
# Discriminator_loss:0.4629
#
# EPOCH[286] - STEP[200]
# Generator_loss:3.7452
# L1_loss:0.0797
# Discriminator_loss:0.4828
#
# EPOCH[286] - STEP[250]
# Generator_loss:4.7401
# L1_loss:0.1027
# Discriminator_loss:0.0744
#
# EPOCH[287] - STEP[50]
# Generator_loss:3.6450
# L1_loss:0.0828
# Discriminator_loss:0.3427
#
# EPOCH[287] - STEP[100]
# Generator_loss:6.2857
# L1_loss:0.0865
# Discriminator_loss:1.3655
#
# EPOCH[287] - STEP[150]
# Generator_loss:4.1889
# L1_loss:0.0818
# Discriminator_loss:0.5622
#
# EPOCH[287] - STEP[200]
# Generator_loss:1.8769
# L1_loss:0.0846
# Discriminator_loss:0.3953
#
# EPOCH[287] - STEP[250]
# Generator_loss:1.9501
# L1_loss:0.0899
# Discriminator_loss:0.3853
#
# EPOCH[288] - STEP[50]
# Generator_loss:3.6569
# L1_loss:0.0769
# Discriminator_loss:0.3674
#
# EPOCH[288] - STEP[100]
# Generator_loss:2.4524
# L1_loss:0.0814
# Discriminator_loss:0.2719
#
# EPOCH[288] - STEP[150]
# Generator_loss:4.9933
# L1_loss:0.0841
# Discriminator_loss:0.6393
#
# EPOCH[288] - STEP[200]
# Generator_loss:2.9753
# L1_loss:0.0875
# Discriminator_loss:0.2333
#
# EPOCH[288] - STEP[250]
# Generator_loss:5.2894
# L1_loss:0.0879
# Discriminator_loss:0.9587
#
# EPOCH[289] - STEP[50]
# Generator_loss:2.0868
# L1_loss:0.0839
# Discriminator_loss:0.2938
#
# EPOCH[289] - STEP[100]
# Generator_loss:5.1576
# L1_loss:0.0771
# Discriminator_loss:0.5995
#
# EPOCH[289] - STEP[150]
# Generator_loss:1.8762
# L1_loss:0.0957
# Discriminator_loss:0.3175
#
# EPOCH[289] - STEP[200]
# Generator_loss:2.4135
# L1_loss:0.0924
# Discriminator_loss:0.4136
#
# EPOCH[289] - STEP[250]
# Generator_loss:2.4754
# L1_loss:0.0952
# Discriminator_loss:0.3052
#
# EPOCH[290] - STEP[50]
# Generator_loss:2.6908
# L1_loss:0.0832
# Discriminator_loss:0.1670
#
# EPOCH[290] - STEP[100]
# Generator_loss:3.3745
# L1_loss:0.0937
# Discriminator_loss:0.3777
#
# EPOCH[290] - STEP[150]
# Generator_loss:2.5714
# L1_loss:0.0803
# Discriminator_loss:0.2664
#
# EPOCH[290] - STEP[200]
# Generator_loss:4.4605
# L1_loss:0.0832
# Discriminator_loss:0.5321
#
# EPOCH[290] - STEP[250]
# Generator_loss:2.3787
# L1_loss:0.0770
# Discriminator_loss:0.5976
#
# EPOCH[291] - STEP[50]
# Generator_loss:3.7803
# L1_loss:0.0837
# Discriminator_loss:0.3357
#
# EPOCH[291] - STEP[100]
# Generator_loss:1.6962
# L1_loss:0.0901
# Discriminator_loss:0.4799
#
# EPOCH[291] - STEP[150]
# Generator_loss:3.0056
# L1_loss:0.0958
# Discriminator_loss:0.1643
#
# EPOCH[291] - STEP[200]
# Generator_loss:2.4652
# L1_loss:0.0810
# Discriminator_loss:0.2131
#
# EPOCH[291] - STEP[250]
# Generator_loss:1.3657
# L1_loss:0.0723
# Discriminator_loss:0.7144
#
# EPOCH[292] - STEP[50]
# Generator_loss:6.4120
# L1_loss:0.0808
# Discriminator_loss:0.2412
#
# EPOCH[292] - STEP[100]
# Generator_loss:1.4525
# L1_loss:0.0849
# Discriminator_loss:0.7160
#
# EPOCH[292] - STEP[150]
# Generator_loss:3.4147
# L1_loss:0.0879
# Discriminator_loss:0.3618
#
# EPOCH[292] - STEP[200]
# Generator_loss:2.4629
# L1_loss:0.0879
# Discriminator_loss:0.2521
#
# EPOCH[292] - STEP[250]
# Generator_loss:2.7481
# L1_loss:0.0777
# Discriminator_loss:0.2169
#
# EPOCH[293] - STEP[50]
# Generator_loss:1.9940
# L1_loss:0.0820
# Discriminator_loss:0.4416
#
# EPOCH[293] - STEP[100]
# Generator_loss:5.0821
# L1_loss:0.0743
# Discriminator_loss:0.3114
#
# EPOCH[293] - STEP[150]
# Generator_loss:4.3581
# L1_loss:0.0790
# Discriminator_loss:0.1922
#
# EPOCH[293] - STEP[200]
# Generator_loss:1.9158
# L1_loss:0.0742
# Discriminator_loss:1.3056
#
# EPOCH[293] - STEP[250]
# Generator_loss:1.8260
# L1_loss:0.0746
# Discriminator_loss:0.5897
#
# EPOCH[294] - STEP[50]
# Generator_loss:1.8007
# L1_loss:0.0878
# Discriminator_loss:0.5050
#
# EPOCH[294] - STEP[100]
# Generator_loss:1.8221
# L1_loss:0.0831
# Discriminator_loss:0.3683
#
# EPOCH[294] - STEP[150]
# Generator_loss:1.9290
# L1_loss:0.0812
# Discriminator_loss:0.3247
#
# EPOCH[294] - STEP[200]
# Generator_loss:0.5874
# L1_loss:0.0819
# Discriminator_loss:1.3507
#
# EPOCH[294] - STEP[250]
# Generator_loss:4.0541
# L1_loss:0.0794
# Discriminator_loss:0.3870
#
# EPOCH[295] - STEP[50]
# Generator_loss:5.6462
# L1_loss:0.0769
# Discriminator_loss:0.1262
#
# EPOCH[295] - STEP[100]
# Generator_loss:5.0133
# L1_loss:0.0971
# Discriminator_loss:0.0733
#
# EPOCH[295] - STEP[150]
# Generator_loss:4.2822
# L1_loss:0.0777
# Discriminator_loss:0.5580
#
# EPOCH[295] - STEP[200]
# Generator_loss:3.7273
# L1_loss:0.1050
# Discriminator_loss:0.1644
#
# EPOCH[295] - STEP[250]
# Generator_loss:2.3860
# L1_loss:0.0914
# Discriminator_loss:0.2940
#
# EPOCH[296] - STEP[50]
# Generator_loss:4.6458
# L1_loss:0.0914
# Discriminator_loss:0.2992
#
# EPOCH[296] - STEP[100]
# Generator_loss:2.7357
# L1_loss:0.0997
# Discriminator_loss:0.2104
#
# EPOCH[296] - STEP[150]
# Generator_loss:6.2516
# L1_loss:0.0876
# Discriminator_loss:0.9987
#
# EPOCH[296] - STEP[200]
# Generator_loss:2.0257
# L1_loss:0.0905
# Discriminator_loss:0.2966
#
# EPOCH[296] - STEP[250]
# Generator_loss:3.0394
# L1_loss:0.0748
# Discriminator_loss:0.5216
#
# EPOCH[297] - STEP[50]
# Generator_loss:3.5379
# L1_loss:0.0879
# Discriminator_loss:0.3441
#
# EPOCH[297] - STEP[100]
# Generator_loss:4.9060
# L1_loss:0.0913
# Discriminator_loss:0.1669
#
# EPOCH[297] - STEP[150]
# Generator_loss:6.9984
# L1_loss:0.1172
# Discriminator_loss:0.0302
#
# EPOCH[297] - STEP[200]
# Generator_loss:3.0086
# L1_loss:0.0845
# Discriminator_loss:0.2523
#
# EPOCH[297] - STEP[250]
# Generator_loss:6.1344
# L1_loss:0.0845
# Discriminator_loss:0.4731
#
# EPOCH[298] - STEP[50]
# Generator_loss:3.4079
# L1_loss:0.0823
# Discriminator_loss:0.4061
#
# EPOCH[298] - STEP[100]
# Generator_loss:2.8282
# L1_loss:0.0702
# Discriminator_loss:0.3079
#
# EPOCH[298] - STEP[150]
# Generator_loss:5.1169
# L1_loss:0.0874
# Discriminator_loss:0.2231
#
# EPOCH[298] - STEP[200]
# Generator_loss:3.7135
# L1_loss:0.0774
# Discriminator_loss:0.4865
#
# EPOCH[298] - STEP[250]
# Generator_loss:5.6435
# L1_loss:0.0800
# Discriminator_loss:0.4832
#
# EPOCH[299] - STEP[50]
# Generator_loss:4.0323
# L1_loss:0.0975
# Discriminator_loss:0.1073
#
# EPOCH[299] - STEP[100]
# Generator_loss:2.2148
# L1_loss:0.0963
# Discriminator_loss:0.2704
#
# EPOCH[299] - STEP[150]
# Generator_loss:2.6650
# L1_loss:0.0821
# Discriminator_loss:0.2673
#
# EPOCH[299] - STEP[200]
# Generator_loss:0.7048
# L1_loss:0.0904
# Discriminator_loss:1.6893
#
# EPOCH[299] - STEP[250]
# Generator_loss:4.1009
# L1_loss:0.0855
# Discriminator_loss:0.1768
#
# EPOCH[300] - STEP[50]
# Generator_loss:5.6360
# L1_loss:0.0833
# Discriminator_loss:0.2540
#
# EPOCH[300] - STEP[100]
# Generator_loss:2.4988
# L1_loss:0.0805
# Discriminator_loss:0.2681
#
# EPOCH[300] - STEP[150]
# Generator_loss:3.0344
# L1_loss:0.0861
# Discriminator_loss:0.3203
#
# EPOCH[300] - STEP[200]
# Generator_loss:4.4319
# L1_loss:0.0881
# Discriminator_loss:0.2038
#
# EPOCH[300] - STEP[250]
# Generator_loss:5.0675
# L1_loss:0.0885
# Discriminator_loss:0.3480

# %%
plt.figure(figsize=(20,30))
for i in range(len(test_img_paths)):
    f = test_img_paths[i]
    sketch, colored = load_img(f)

    pred = generator(tf.expand_dims(sketch, 0))
    pred = denormalize(pred)

    plt.subplot(5,3,3*i+1); plt.imshow(denormalize(sketch))
    plt.subplot(5,3,3*i+2); plt.imshow(pred[0])
    plt.subplot(5,3,3*i+3); plt.imshow(denormalize(colored))

# %% [markdown]
# - 학습 횟수가 부족해서 그런지 이미지를 잘 생성하지 못함
